# %% [markdown]
# <a href="https://colab.research.google.com/github/monahusein/Hw/blob/main/Task8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 344856      ZWE    Africa     Zimbabwe  2023-09-23     265748.0        0.0
# 344857      ZWE    Africa     Zimbabwe  2023-09-24     265748.0        0.0
# 344858      ZWE    Africa     Zimbabwe  2023-09-25     265748.0        0.0
# 344859      ZWE    Africa     Zimbabwe  2023-09-26     265748.0        0.0
# 344860      ZWE    Africa     Zimbabwe  2023-09-27     265748.0        0.0
#
# ...

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 344856      ZWE    Africa  Zimbabwe  2023-09-23     265748.0        0.0
# 344857      ZWE    Africa  Zimbabwe  2023-09-24     265748.0        0.0
# 344858      ZWE    Africa  Zimbabwe  2023-09-25     265748.0        0.0
# 344859      ZWE    Africa  Zimbabwe  2023-09-26     265748.0        0.0
# 344860      ZWE    Africa  Zimbabwe  2023-09-27     265748.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 344856                 0.0        5718.0         0.0                  0.0
# 344857                 0.0        5718.0         0.0                  0.0
# 344858                 0.0        5718.0         0.0                  0.0
# 344859                 0.0        5718.0         0.0                  0.0
# 344860                 0.0        5718.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344861 entries, 0 to 344860
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    344861 non-null  object
#  1   continent                                   328453 non-null  object
#  2   location                                    344861 non-null  object
#  3   date                                        344861 non-null  object
#  4   total_cases                                 306964 non-null  float64
#  5   new_cases                                   335338 non-null  float64
#  6   new_cases_smoothed                          334079 non-null  float64
#  7   total_deaths                                285503 non-null  float64
#  8   new_deaths                                  335378 non-null  float64
# ...

# %%
df.shape
# Out:
# (344861, 67)

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  3.069640e+05  3.353380e+05        3.340790e+05  2.855030e+05
# mean   6.571274e+06  9.740990e+03        9.777569e+03  8.538039e+04
# std    4.013913e+07  1.111088e+05        9.519139e+04  4.371278e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    7.910000e+03  0.000000e+00        2.860000e-01  1.250000e+02
# 50%    6.889000e+04  2.000000e+00        2.600000e+01  1.302000e+03
# 75%    7.269022e+05  2.760000e+02        5.151430e+02  1.174400e+04
# max    7.708747e+08  8.401961e+06        6.402036e+06  6.959303e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  335378.000000        334148.000000            306964.000000
# mean       86.777994            87.093917            100066.612321
# std       618.277391           563.307165            149790.634356
# min         0.000000             0.000000                 0.000000
# ...

# %%
df.sample(15)
# Out:
#        iso_code      continent        location        date  total_cases  \
# 153782      JOR           Asia          Jordan  2023-01-03    1746997.0
# 44258       BRN           Asia          Brunei  2021-08-18        946.0
# 98544       FRO         Europe  Faeroe Islands  2021-01-14        650.0
# 285507      ZAF         Africa    South Africa  2021-05-18    1615485.0
# 251111      ROU         Europe         Romania  2020-05-21      17387.0
# 324209      GBR         Europe  United Kingdom  2022-10-21   23864809.0
# 171543      LIE         Europe   Liechtenstein  2023-02-01      21359.0
# 259446      LCA  North America     Saint Lucia  2020-10-19         33.0
# 117899      GRL  North America       Greenland  2021-09-27        565.0
# 312809      TUN         Africa         Tunisia  2021-06-20     381175.0
# 5126        DZA         Africa         Algeria  2022-11-02     270840.0
# 167575      LSO         Africa         Lesotho  2023-06-05      34490.0
# ...

# %%
df.describe().T
# Out:
#                                             count          mean           std  \
# total_cases                              306964.0  6.571274e+06  4.013913e+07
# new_cases                                335338.0  9.740990e+03  1.111088e+05
# new_cases_smoothed                       334079.0  9.777569e+03  9.519139e+04
# total_deaths                             285503.0  8.538039e+04  4.371278e+05
# new_deaths                               335378.0  8.677799e+01  6.182774e+02
# ...                                           ...           ...           ...
# population                               344861.0  1.284284e+08  6.607026e+08
# excess_mortality_cumulative_absolute      11944.0  5.113397e+04  1.443228e+05
# excess_mortality_cumulative               11944.0  9.738000e+00  1.238457e+01
# excess_mortality                          11944.0  1.146195e+01  2.536237e+01
# excess_mortality_cumulative_per_million   11944.0  1.644920e+03  1.927691e+03
#
# ...

# %%
df.head(7).style.background_gradient(cmap='YlOrBr')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3931: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3932: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...

# %%
df['location']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 344856       Zimbabwe
# 344857       Zimbabwe
# 344858       Zimbabwe
# 344859       Zimbabwe
# 344860       Zimbabwe
# Name: location, Length: 344861, dtype: object

# %%
df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df['location'].nunique()
# Out:
# 255

# %%
df['continent'].unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
df_palestine=df[df.location=='Palestine']

# %%
df_palestine
# Out:
#        iso_code continent   location        date  total_cases  new_cases  \
# 234596      PSE      Asia  Palestine  2020-01-03          NaN        0.0
# 234597      PSE      Asia  Palestine  2020-01-04          NaN        0.0
# 234598      PSE      Asia  Palestine  2020-01-05          NaN        0.0
# 234599      PSE      Asia  Palestine  2020-01-06          NaN        0.0
# 234600      PSE      Asia  Palestine  2020-01-07          NaN        0.0
# ...         ...       ...        ...         ...          ...        ...
# 235955      PSE      Asia  Palestine  2023-09-23     703228.0        0.0
# 235956      PSE      Asia  Palestine  2023-09-24     703228.0        0.0
# 235957      PSE      Asia  Palestine  2023-09-25     703228.0        0.0
# 235958      PSE      Asia  Palestine  2023-09-26     703228.0        0.0
# 235959      PSE      Asia  Palestine  2023-09-27     703228.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_palestine['new_deaths'].max()
# Out:
# 34.0

# %%
df_palestine[df_palestine['new_deaths'] == df_palestine['new_deaths'].max()]['date']
# Out:
# 235068    2021-04-19
# Name: date, dtype: object

# %%
df_palestine[df_palestine['new_deaths'] == df_palestine['new_deaths'].max()]['icu_patients']
# Out:
# 235068   NaN
# Name: icu_patients, dtype: float64

# %%
df_palestine['female_smokers'].count()
# Out:
# 0

# %%
df_palestine['male_smokers'].count()
# Out:
# 0

# %%
df_palestine['people_fully_vaccinated']
# Out:
# 234596   NaN
# 234597   NaN
# 234598   NaN
# 234599   NaN
# 234600   NaN
#           ..
# 235955   NaN
# 235956   NaN
# 235957   NaN
# 235958   NaN
# 235959   NaN
# Name: people_fully_vaccinated, Length: 1364, dtype: float64

# %%
df_palestine['population'].unique()
# Out:
# array([5250076.])

# %%
df_palestine['weekly_hosp_admissions'].max()
# Out:
# nan

# %%
df_palestine['weekly_hosp_admissions'].min()
# Out:
# nan

# %%
df_palestine['total_deaths']
# Out:
# 234596       NaN
# 234597       NaN
# 234598       NaN
# 234599       NaN
# 234600       NaN
#            ...
# 235955    5708.0
# 235956    5708.0
# 235957    5708.0
# 235958    5708.0
# 235959    5708.0
# Name: total_deaths, Length: 1364, dtype: float64

# %%
df_palestine['total_deaths'].max()
# Out:
# 5708.0

# %%
df_palestine['total_deaths'].mean()
# Out:
# 3892.1234375
