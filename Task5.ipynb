# %% [markdown]
# <a href="https://colab.research.google.com/github/monahusein/Hw/blob/main/Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import numpy as np
s1 = pd.Series([10, 11, 12, 13, 14])

print(f's1:\n {s1}')
print ("*"*50)
s2 = pd.Series([1, 2, 3], index=['first','second', 'third'])
print(f's2:\n {s2}')
print ("*"*50)
s3 = pd.Series({'a':3 , 'b':4, 'c':5})
print(f's3:\n {s3}')
print("*"*50)
s4 = pd.Series(42, range(10), name = 's4')
print(f's4:\n {s4}')


print(s3.size)
print(s3.shape)
print(s3.dtype)
print(s3.index)
print("*"*50)


j = [10, 11, 12, 13, 14]

pd.Series(j)
print(j)
print("*"*50)

s3 = pd.Series({'a':3.0, 'b':4, 'c':5})
print(f's3:\n {s3}')

print('*'*50)

print(s3.size)
print(s3.shape)
print(s3.dtype)
print(s3.index)
print ("*"*50)
print(s3 [  ['b', 'c'] ])
print("*"*50)
print(s3 [  ['b', 'c'] ])
print("*"*50)
print(s3[s3 > 4])
print("*"*50)
print(s3 == 5)
print("*"*50)
print(s3[s3 < s3.mean()])
print("*"*50)
df = pd.DataFrame([ [1, 2, 3], [4, 5, 6] ])
print(df)
print("*"*50)
ar = np.array([ [1, 2, 3], [4, 5, 6], [5, 20, 1] ])

print(pd.DataFrame(ar, columns=['sami', 'majd', 'ali'],index=['mona', 'mhmd', 'gmal']))
print("*"*50)

print(pd.DataFrame(ar , columns= " A  B  C ".split( ) , index= " r1 r2 r3 ".split( ) ))
s1 = pd.Series([1, 2], index=['first','second'])
print("*"*50)

s2 = pd.Series([1, 3], index=['first','second'])
s3 = pd.Series([2, 3], index=['first','second'])


print(pd.DataFrame({'a':s1, 'c':s3}) )
print("*"*50)
ar = np.random.randint(0, 100000 , 10000).reshape((2500, 4))


df=pd.DataFrame(ar, columns=['a', 'b', 'c', 'd'])
print(df)
print("*"*50)
df.iloc[2499, 3] = np.nan
print(df)
print("*"*50)
print(df.head())
print("*"*50)
print (df.head(19))
df.head(10).style.background_gradient(cmap='Reds')
print(df)
print(df.tail())
print("*"*50)
df.tail(10).style.background_gradient(cmap='Greens')
print(df.sample())
df.shape
df.columns
df.info()
df.isnull()
df.isnull().sum()
df.dropna(axis = 1)
df.fillna(value = '678' , inplace = False)
df

df.replace(np.nan, 98, inplace=True)
df

df.iloc[1, 3] = np.nan
df.iloc[2, 1] = np.nan
print("*"*50)

#import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)

y = x**2

x
y

df = pd.DataFrame(np.array([x, y]).T, columns=['a', 'b'])
df.plot()

x = np.random.rand(10)
y = np.random.rand(10)

df = pd.DataFrame(np.array([x, y]).T, columns=['a', 'b'])

x = np.random.rand(10)
y = np.random.rand(10)

df = pd.DataFrame(np.array([x, y]).T, columns=['a', 'b'])
df.plot.hist()

ar = np.arange(10000).reshape((100, 100))
#ar = np.random.randint(0, 1000012 , 100000).reshape((10, 10))
#np.random.rand(100000).reshape((10, 10))

df = pd.DataFrame(np.array([x,y]), columns=['a', 'b', 'c', 'd','q', 'k', 'h', 'o','i', 'p'])
df.plot()
# Out:
# s1:
#  0    10
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int64
# **************************************************
# s2:
#  first     1
# second    2
# third     3
# dtype: int64
# **************************************************
# s3:
#  a    3
# b    4
# c    5
# dtype: int64
# **************************************************
# s4:
#  0    42
# 1    42
# 2    42
# 3    42
# 4    42
# 5    42
# 6    42
# 7    42
# 8    42
# 9    42
# Name: s4, dtype: int64
# 3
# (3,)
# int64
# Index(['a', 'b', 'c'], dtype='object')
# **************************************************
# [10, 11, 12, 13, 14]
# **************************************************
# s3:
#  a    3.0
# b    4.0
# c    5.0
# dtype: float64
# **************************************************
# 3
# (3,)
# float64
# Index(['a', 'b', 'c'], dtype='object')
# **************************************************
# b    4.0
# c    5.0
# dtype: float64
# **************************************************
# b    4.0
# ...
